# %% [markdown]
# # **1- Load & Read the Dataset**

# %%
import pandas as pd

file_path = "C:/Users/Raghad/OneDrive - University of Jeddah/BI Bootcamp-Raghad/Capstone Project/group1_dataset_retailmarketinganalysis.xlsx"
df = pd.read_excel(file_path, sheet_name='Retail_Dataset')

# %%
df.head()
# Out:
#    Transaction_ID  Customer_ID      Customer_Name      Customer_Email  \
# 0         4155845        80175        Diane Clark  Martin39@gmail.com
# 1         4969987        64995        Justin Lara   Jacob26@gmail.com
# 2         9476855        42410  Anthony Rodriguez   Paula49@gmail.com
# 3         3413296        98256        Steven Boyd  Sheryl18@gmail.com
# 4         4580441        12911   Chelsea Cummings  Daniel55@gmail.com
#
#    Customer_Phone                          Address        City  \
# 0      6219779557     8823 Mariah Heights Apt. 263  Wollongong
# 1      2683281702        3577 Cole Stream Apt. 351  Portsmouth
# 2      3745118170        585 Malik Lodge Suite 186  Portsmouth
# 3      5248581519  1719 Christina Heights Apt. 614  Portsmouth
# 4      9050662623                     336 Sara Run  Portsmouth
#
#              State  Zipcode    Country  ... Payment_Method  Order_Status  \
# 0  New South Wales  39820.0  Australia  ...           Cash     Delivered
# ...

# %% [markdown]
# # **2- Data Exploration**

# %% [markdown]
# **Shape of the Data**

# %%
df.shape
# Out:
# (85745, 39)

# %% [markdown]
# **Columns Data Types**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85745 entries, 0 to 85744
# Data columns (total 39 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Transaction_ID                 85745 non-null  int64
#  1   Customer_ID                    85745 non-null  int64
#  2   Customer_Name                  85745 non-null  object
#  3   Customer_Email                 85745 non-null  object
#  4   Customer_Phone                 85745 non-null  int64
#  5   Address                        85745 non-null  object
#  6   City                           85745 non-null  object
#  7   State                          85745 non-null  object
#  8   Zipcode                        85653 non-null  float64
#  9   Country                        85656 non-null  object
#  10  Age Range                      85745 non-null  object
#  11  Age                            85745 non-null  int64
# ...

# %% [markdown]
# **Statistical Summary**

# %%
df.describe()
# Out:
#        Transaction_ID   Customer_ID  Customer_Phone       Zipcode  \
# count    8.574500e+04  85745.000000    8.574500e+04  85653.000000
# mean     5.492721e+06  55011.665555    5.497643e+09  50456.271678
# min      1.000195e+06  10000.000000    1.000311e+09    503.000000
# 25%      3.249942e+06  32500.000000    3.252710e+09  25517.000000
# 50%      5.498569e+06  55030.000000    5.490187e+09  51004.000000
# 75%      7.740362e+06  77519.000000    7.744940e+09  75517.000000
# max      9.999945e+06  99999.000000    9.999791e+09  99949.000000
# std      2.596410e+06  25990.610960    2.594026e+09  28998.736027
#
#                 Age                           Date          Year  \
# count  85745.000000                          85657  85652.000000
# mean      41.171928  2023-08-30 17:42:32.239747072   2023.164246
# min       18.000000            2023-03-01 00:00:00   2023.000000
# 25%       26.000000            2023-05-31 00:00:00   2023.000000
# ...

# %% [markdown]
# **Check & Handle Missing Values**

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()

# Display columns with missing values only
missing_values = missing_values[missing_values > 0]

print("Columns with missing values:")
print(missing_values)
# Out:
# Columns with missing values:
# Zipcode              92
# Country              89
# Income               96
# Customer_Segment     90
# Date                 88
# Year                 93
# Month                66
# Time                101
# Amount              119
# Product_Category     79
# Feedback             52
# Shipping_Method      91
# dtype: int64

# %%
# Fill Customer_Segment with the most frequent value
df['Customer_Segment'] = df['Customer_Segment'].fillna(df['Customer_Segment'].mode()[0])

# Fill Shipping_Method with the most frequent value
df['Shipping_Method'] = df['Shipping_Method'].fillna(df['Shipping_Method'].mode()[0])

# Fill Feedback with "No Feedback"
df['Feedback'] = df['Feedback'].fillna('No Feedback')

# Drop rows with missing values in other columns
columns_to_drop_missing = ['Zipcode', 'Country', 'Income', 'Date', 'Year', 'Month', 'Time', 'Amount', 'Product_Category']
df = df.dropna(subset=columns_to_drop_missing)

# Verify that no missing values remain
print("Missing values after processing:")
print(df.isnull().sum())
# Out:
# Missing values after processing:
# Transaction_ID                   0
# Customer_ID                      0
# Customer_Name                    0
# Customer_Email                   0
# Customer_Phone                   0
# Address                          0
# City                             0
# State                            0
# Zipcode                          0
# Country                          0
# Age Range                        0
# Age                              0
# Gender                           0
# Income                           0
# Customer_Segment                 0
# Date                             0
# Year                             0
# Month                            0
# Time                             0
# Total_Purchases                  0
# Product_Cost                     0
# Amount                           0
# Revenue                          0
# Profit                           0
# Product_Category                 0
# Product_Brand                    0
# ...

# %% [markdown]
# **Check Unique Values in Categorical Columns**

# %%
# Check unique values in categorical columns
categorical_columns = ['Country', 'Customer_Segment', 'Product_Category', 'Feedback', 'Shipping_Method']  # Add other categorical columns if necessary

for col in categorical_columns:
    unique_values = df[col].unique()
    print(f"Unique values in '{col}':")
    print(unique_values)
    print("Number of unique values:", len(unique_values))
    print("-" * 50)
# Out:
# Unique values in 'Country':
# ['Australia' 'UK' 'Canada' 'Germany' 'USA']
# Number of unique values: 5
# --------------------------------------------------
# Unique values in 'Customer_Segment':
# ['New' 'Regular' 'Premium']
# Number of unique values: 3
# --------------------------------------------------
# Unique values in 'Product_Category':
# ['Grocery' 'Books' 'Clothing' 'Electronics' 'Home Decor']
# Number of unique values: 5
# --------------------------------------------------
# Unique values in 'Feedback':
# ['Bad' 'Good' 'Excellent' 'No Feedback']
# Number of unique values: 4
# --------------------------------------------------
# Unique values in 'Shipping_Method':
# ['Standard' 'Express']
# Number of unique values: 2
# --------------------------------------------------

# %% [markdown]
# **Identify & Handle Duplicates**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # **3- Save the Cleaned Dataset**

# %%
# Define the path to the folder on your desktop
output_path = "C:/Users/Raghad/OneDrive - University of Jeddah/BI Bootcamp-Raghad/Capstone Project/group1_dataset_retailmarketinganalysis.xlsx"

# Save the cleaned DataFrame to the specified path
df.to_excel(output_path, index=False)

print(f"Cleaned data has been saved to {output_path}")
# Out:
# Cleaned data has been saved to C:/Users/Raghad/OneDrive - University of Jeddah/BI Bootcamp-Raghad/Capstone Project/group1_dataset_retailmarketinganalysis.xlsx
